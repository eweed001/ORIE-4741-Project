# %%
#Importing packages
import pandas as pd
pd.set_option('display.max_columns', 100)
import numpy as np
import matplotlib.pyplot as plt

# %%
#Reading in csvs
mich = pd.read_csv('data/usa-2016-presidential-election-by-county-Michigan.csv', delimiter = ';')
fl = pd.read_csv('data/usa-2016-presidential-election-by-county.csv', delimiter = ';')
pa = pd.read_csv('data/usa-2016-presidential-election-by-county-Pennsylvania.csv', delimiter = ';')

# %%
mich.head()
# Out:
#       State  ST   Fips                         County  Precincts  Votes  \
# 0  Michigan  MI  26141  Presque Isle County, Michigan         17   7215
# 1  Michigan  MI  26025       Calhoun County, Michigan         62  58786
# 2  Michigan  MI  26023        Branch County, Michigan         22  16490
# 3  Michigan  MI  26155    Shiawassee County, Michigan         35  34044
# 4  Michigan  MI  26097      Mackinac County, Michigan         14   6088
#
#    Democrats 08 (Votes)  Democrats 12 (Votes)  Republicans 08 (Votes)  \
# 0                  3722                  3192                    3606
# 1                 34561                 29267                   28553
# 2                  8413                  6913                    9534
# 3                 19397                 17197                   16268
# 4                  3027                  2652                    3268
#
#    Republicans 12 (Votes)  ...  total08  total12  other08  other12  \
# ...

# %%
pa.head()
# Out:
#           State  ST   Fips                           County  Precincts  \
# 0  Pennsylvania  PA  42045    Delaware County, Pennsylvania        429
# 1  Pennsylvania  PA  42127       Wayne County, Pennsylvania         35
# 2  Pennsylvania  PA  42015    Bradford County, Pennsylvania         61
# 3  Pennsylvania  PA  42069  Lackawanna County, Pennsylvania        163
# 4  Pennsylvania  PA  42021     Cambria County, Pennsylvania        133
#
#     Votes  Democrats 08 (Votes)  Democrats 12 (Votes)  Republicans 08 (Votes)  \
# 0  284832                178870                171792                  115273
# 1   22365                  9892                  8396                   12702
# 2   25399                 10306                  8624                   15057
# 3  102740                 67520                 61838                   39488
# 4   60167                 32451                 24249                   31995
#
#    Republicans 12 (Votes)  ...  total08  total12  other08  other12  \
# ...

# %%
fl.head()
# Out:
#      State  ST   Fips                     County  Precincts   Votes  \
# 0  Florida  FL  12031      Duval County, Florida        199  428734
# 1  Florida  FL  12037   Franklin County, Florida          8    6003
# 2  Florida  FL  12111  St. Lucie County, Florida         64  140731
# 3  Florida  FL  12095     Orange County, Florida        247  545800
# 4  Florida  FL  12007   Bradford County, Florida         14   12098
#
#    Democrats 08 (Votes)  Democrats 12 (Votes)  Republicans 08 (Votes)  \
# 0                202618                196737                  210537
# 1                  2134                  1845                    3818
# 2                 67125                 65869                   52512
# 3                273009                273665                  186832
# 4                  3430                  3325                    8136
#
#    Republicans 12 (Votes)  ...  total08  total12  other08  other12  \
# ...

# %%
#Viewing all the column names, last 60 were not listed on website..? Will drop them
lst = list(mich.columns)
lst
# Out:
# ['State',
#  'ST',
#  'Fips',
#  'County',
#  'Precincts',
#  'Votes',
#  'Democrats 08 (Votes)',
#  'Democrats 12 (Votes)',
#  'Republicans 08 (Votes)',
#  'Republicans 12 (Votes)',
#  'Republicans 2016',
#  'Democrats 2016',
#  'Green 2016',
#  'Libertarians 2016',
#  'Republicans 2012',
#  'Republicans 2008',
#  'Democrats 2012',
#  'Democrats 2008',
#  'Less Than High School Diploma',
#  'At Least High School Diploma',
#  "At Least Bachelors's Degree",
#  'Graduate Degree',
#  'School Enrollment',
#  'Median Earnings 2010',
#  'White (Not Latino) Population',
#  'African American Population',
#  'Native American Population',
#  'Asian American Population',
#  'Other Race or Races',
#  'Latino Population',
#  'Children Under 6 Living in Poverty',
#  'Adults 65 and Older Living in Poverty',
#  'Total Population',
#  'Preschool.Enrollment.Ratio.enrolled.ages.3.and.4',
#  'Poverty.Rate.below.federal.poverty.threshold',
#  'Gini.Coefficient',
# ...

# %%
lst[99:]
# Out:
# ['Nearest County',
#  'temp',
#  'precip',
#  'Temp Bins',
#  'Lat Bins',
#  'Lon Bins',
#  'Precip Bins',
#  'Elevation Bins',
#  'Geo Shape',
#  'Name 16',
#  'reporting',
#  'Votes16 Trumpd',
#  'Votes16 Clintonh',
#  'Votes16 Johnsong',
#  'Votes16 Steinj',
#  'Votes16 Castled',
#  'Votes16 De La Fuenter',
#  'Est Votes Remaining',
#  'Votes16 Mcmulline',
#  'Votes16 Hedgesj',
#  'Votes16 Kahnl',
#  'Votes16 La Rivag',
#  'Votes16 Hoeflingt',
#  'Votes16 Kenistonc',
#  'Votes16 Smithm',
#  'Votes16 Atwoodf',
#  'Votes16 Kennedya',
#  'Votes16 Kopitkek',
#  'Votes16 Kotlikoffl',
#  'Votes16 Lyttleb',
#  'Votes16 Maldonadoj',
#  'Votes16 Maturenm',
#  'Votes16 Scottr',
#  'Votes16 Silvar',
#  'Votes16 Soltysike',
#  'Votes16 Vacekd',
#  'Votes16 Copelands',
#  'Votes16 Jacobp',
#  'Votes16 Whitej',
#  'Votes16 Mooreheadm',
#  'Votes16 None Of These Candidates',
#  'Votes16 Duncanr',
#  'Votes16 Skewesp',
#  'Votes16 Giordanir',
#  'total16',
#  'Other16 Frac',
#  'Rep16 Frac2',
# ...

# %%
len(lst)
cols = list(range(99,159))

# %%
#Dropping last 60 columns that are not useful
mich = mich.drop(mich.columns[cols], axis = 1)
fl = fl.drop(fl.columns[cols], axis = 1)
pa = pa.drop(pa.columns[cols], axis = 1)

# %%
mich.head()
# Out:
#       State  ST   Fips                         County  Precincts  Votes  \
# 0  Michigan  MI  26141  Presque Isle County, Michigan         17   7215
# 1  Michigan  MI  26025       Calhoun County, Michigan         62  58786
# 2  Michigan  MI  26023        Branch County, Michigan         22  16490
# 3  Michigan  MI  26155    Shiawassee County, Michigan         35  34044
# 4  Michigan  MI  26097      Mackinac County, Michigan         14   6088
#
#    Democrats 08 (Votes)  Democrats 12 (Votes)  Republicans 08 (Votes)  \
# 0                  3722                  3192                    3606
# 1                 34561                 29267                   28553
# 2                  8413                  6913                    9534
# 3                 19397                 17197                   16268
# 4                  3027                  2652                    3268
#
#    Republicans 12 (Votes)  ...  Winter Tmin  Summer Tavg  Summer Tmax  \
# ...

# %%
#Reading in GDP csvs
fl_gdp = pd.read_csv('data/FL_GDP.csv')
pa_gdp = pd.read_csv('data/PA_GDP.csv')
mi_gdp = pd.read_csv('data/MI_GDP.csv')

# %%
fl_gdp.head()
# Out:
#     GeoFIPS  GeoName  Region TableName  LineCode IndustryClassification  \
# 0   "12000"  Florida     5.0    CAGDP2       1.0                    ...
# 1   "12000"  Florida     5.0    CAGDP2       2.0                    ...
# 2   "12000"  Florida     5.0    CAGDP2       3.0                     11
# 3   "12000"  Florida     5.0    CAGDP2       6.0                     21
# 4   "12000"  Florida     5.0    CAGDP2      10.0                     22
#
#                                        Description                  Unit  \
# 0                               All industry total  Thousands of dollars
# 1                               Private industries  Thousands of dollars
# 2       Agriculture, forestry, fishing and hunting  Thousands of dollars
# 3    Mining, quarrying, and oil and gas extraction  Thousands of dollars
# 4                                        Utilities  Thousands of dollars
#
#         2001       2002  ...       2009       2010       2011       2012  \
# ...

# %%
# Getting just rows that represent all Industry total GDP for each state
fl_gdp = fl_gdp.loc[fl_gdp['Description'] == 'All industry total']
pa_gdp = pa_gdp.loc[pa_gdp['Description'] == 'All industry total']
mi_gdp = mi_gdp.loc[mi_gdp['Description'] == 'All industry total']

# %%
mi_gdp.head()
# Out:
#       GeoFIPS      GeoName  Region TableName  LineCode IndustryClassification  \
# 0     "26000"     Michigan     3.0    CAGDP2       1.0                    ...
# 34    "26001"   Alcona, MI     3.0    CAGDP2       1.0                    ...
# 68    "26003"    Alger, MI     3.0    CAGDP2       1.0                    ...
# 102   "26005"  Allegan, MI     3.0    CAGDP2       1.0                    ...
# 136   "26007"   Alpena, MI     3.0    CAGDP2       1.0                    ...
#
#             Description                  Unit       2001       2002  ...  \
# 0    All industry total  Thousands of dollars  348528981  362271106  ...
# 34   All industry total  Thousands of dollars     156606     165469  ...
# 68   All industry total  Thousands of dollars     227842     234731  ...
# 102  All industry total  Thousands of dollars    2633211    2724201  ...
# 136  All industry total  Thousands of dollars     778195     803799  ...
#
# ...

# %%
#Dropping unnecessary columns from above
fl_gdp = fl_gdp.drop(['Region', 'TableName', 'LineCode', 'IndustryClassification'], axis = 1)
pa_gdp = pa_gdp.drop(['Region', 'TableName', 'LineCode', 'IndustryClassification'], axis = 1)
mi_gdp = mi_gdp.drop(['Region', 'TableName', 'LineCode', 'IndustryClassification'], axis = 1)

# %%
fl_gdp.head()
# Out:
#       GeoFIPS       GeoName         Description                  Unit  \
# 0     "12000"       Florida  All industry total  Thousands of dollars
# 34    "12001"   Alachua, FL  All industry total  Thousands of dollars
# 68    "12003"     Baker, FL  All industry total  Thousands of dollars
# 102   "12005"       Bay, FL  All industry total  Thousands of dollars
# 136   "12007"  Bradford, FL  All industry total  Thousands of dollars
#
#           2001       2002       2003       2004       2005       2006  ...  \
# 0    516689571  548540329  583725706  635525532  696741064  744464172  ...
# 34     7059330    7452846    7669735    8600253    9131860    9885411  ...
# 68      339668     363804     378263     407143     437021     485144  ...
# 102    4371307    4749763    5082011    5683337    6315753    6863244  ...
# 136     405117     428196     458097     501514     537797     595882  ...
#
#           2009       2010       2011       2012       2013       2014  \
# ...

# %%
# Data set that has data from 2004, 2008, and 2012 elections by county
df = pd.read_csv('data/by_county-2004-2012.csv')

# %%
df.head()
# Out:
#    year state          county   fips  vote_rep  vote_dem  vote_oth  \
# 0  2004    AL  Autauga County  01001     15196      4758       127
# 1  2004    AL  Baldwin County  01003     52971     15599       750
# 2  2004    AL  Barbour County  01005      5899      4832        46
# 3  2004    AL     Bibb County  01007      5472      2089        39
# 4  2004    AL   Blount County  01009     17386      3938       180
#
#    vote_total  pct_rep  pct_dem  pct_oth winner runnerup  pct_winner  \
# 0       20081     75.7     23.7      0.6    rep      dem        75.7
# 1       69320     76.4     22.5      1.1    rep      dem        76.4
# 2       10777     54.7     44.8      0.4    rep      dem        54.7
# 3        7600     72.0     27.5      0.5    rep      dem        72.0
# 4       21504     80.9     18.3      0.8    rep      dem        80.9
#
#    margin_winner_over_runnerup
# 0                         52.0
# 1                         53.9
# 2                          9.9
# ...

# %%
#Spliting by states
pa_older = df.loc[df['state'] == 'PA']
fl_older = df.loc[df['state'] == 'FL']
mi_older = df.loc[df['state'] == 'MI']

# %%
pa_older.head()
# Out:
#       year state            county   fips  vote_rep  vote_dem  vote_oth  \
# 2215  2004    PA      Adams County  42001     28247     13764       217
# 2216  2004    PA  Allegheny County  42003    271925    368912      4632
# 2217  2004    PA  Armstrong County  42005     18925     12025       147
# 2218  2004    PA     Beaver County  42007     39916     42146       481
# 2219  2004    PA    Bedford County  42009     16606      6016        57
#
#       vote_total  pct_rep  pct_dem  pct_oth winner runnerup  pct_winner  \
# 2215       42228     66.9     32.6      0.5    rep      dem        66.9
# 2216      645469     42.1     57.2      0.7    dem      rep        57.2
# 2217       31097     60.9     38.7      0.5    rep      dem        60.9
# 2218       82543     48.4     51.1      0.6    dem      rep        51.1
# 2219       22679     73.2     26.5      0.3    rep      dem        73.2
#
#       margin_winner_over_runnerup
# 2215                         34.3
# ...
